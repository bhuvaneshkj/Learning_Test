# %%
import pandas as pd
import numpy as np

# %%
df = pd. read_csv('F:\Machine Learning\DAT210x-master\Module2\Datasets\direct_marketing.csv')
df.head(10)
# Out:
#    recency history_segment  history  mens  womens   zip_code  newbie channel  \
# 0       10  2) $100 - $200   142.44     1       0  Surburban       0   Phone
# 1        6  3) $200 - $350   329.08     1       1      Rural       1     Web
# 2        7  2) $100 - $200   180.65     0       1  Surburban       1     Web
# 3        9  5) $500 - $750   675.83     1       0      Rural       1     Web
# 4        2    1) $0 - $100    45.34     1       0      Urban       0     Web
# 5        6  2) $100 - $200   134.83     0       1  Surburban       0   Phone
# 6        9  3) $200 - $350   280.20     1       0  Surburban       1   Phone
# 7        9    1) $0 - $100    46.42     0       1      Urban       0   Phone
# 8        9  5) $500 - $750   675.07     1       1      Rural       1   Phone
# 9       10    1) $0 - $100    32.84     0       1      Urban       1     Web
#
#          segment  visit  conversion  spend  DM_category
# 0  Womens E-Mail      0           0    0.0            4
# ...

# %%
mean= df["recency"].mean()
mean
# Out:
# 5.763734375

# %%
df["recency"]=df["recency"].replace(np.nan,mean)
a =df[(df["recency"]>7)& (df["newbie"]==1)]
a
# Out:
#        recency   history_segment  history  mens  womens   zip_code  newbie  \
# 3            9    5) $500 - $750   675.83     1       0      Rural       1
# 6            9    3) $200 - $350   280.20     1       0  Surburban       1
# 8            9    5) $500 - $750   675.07     1       1      Rural       1
# 9           10      1) $0 - $100    32.84     0       1      Urban       1
# 20           9      1) $0 - $100    29.99     0       1  Surburban       1
# 33           9      1) $0 - $100    29.99     1       0  Surburban       1
# 38          10      1) $0 - $100    63.79     1       0      Rural       1
# 40          11    3) $200 - $350   236.97     1       1      Urban       1
# 58           9    5) $500 - $750   506.83     1       0      Rural       1
# 64           9      1) $0 - $100    61.57     1       0  Surburban       1
# 67          11      1) $0 - $100    53.81     1       0      Urban       1
# ...

# %%
a= df["history_segment"]
a.dtypes
# Out:
# dtype('O')

# %% [markdown]
# # Normalization

# %%
# min max
df["history"]=(df["history"]-df["history"].min())/(df["history"].max()-df["history"].min())
df["history"].head(10)
# Out:
# 0    0.033912
# 1    0.090198
# 2    0.045435
# 3    0.194768
# 4    0.004629
# 5    0.031617
# 6    0.075457
# 7    0.004955
# 8    0.194539
# 9    0.000859
# Name: history, dtype: float64

# %%
df["history"]=df["history"]/df["history"].max()
df["history"].head(10)
# Out:
# 0    0.033912
# 1    0.090198
# 2    0.045435
# 3    0.194768
# 4    0.004629
# 5    0.031617
# 6    0.075457
# 7    0.004955
# 8    0.194539
# 9    0.000859
# Name: history, dtype: float64

# %%
df["history"]=(df["history"]-df["history"].mean())/df["history"].max()
df["history"].head(10)
# Out:
# 0   -0.030051
# 1    0.026235
# 2   -0.018527
# 3    0.130806
# 4   -0.059333
# 5   -0.032345
# 6    0.011494
# 7   -0.059008
# 8    0.130577
# 9   -0.063103
# Name: history, dtype: float64

# %%
df["recency"].min()
# Out:
# 1

# %%
bins_bandwidth=(df["DM_category"].max()-df["DM_category"].min())/5
bins= range(min(df["DM_category"])-min(df["DM_category"]),bins_bandwidth)
bins
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-b14d68d31309> in <module>
#       1 bins_bandwidth=(df["DM_category"].max()-df["DM_category"].min())/5
# ----> 2 bins= range(min(df["DM_category"])-min(df["DM_category"]),bins_bandwidth)
#       3 bins
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer

# %%
pd.get_dummies(df["zip_code"]).head(5)
# Out:
#    Rural  Surburban  Urban
# 0      0          1      0
# 1      1          0      0
# 2      0          1      0
# 3      1          0      0
# 4      0          0      1
